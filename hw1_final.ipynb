# %%
from ultralytics import YOLO
import cv2
import numpy as np
import torch
import matplotlib.pyplot as plt
import os
def detect_sign(yolo_path, frame):
    # 加载模型
    yolo = YOLO(yolo_path)
    
    # 读取图片
    img = cv2.imread(frame) if isinstance(frame, str) else frame
    
    # 进行预测
    results = yolo.predict(img)[0]  # 只获取第一个结果
    
    # 在图片上绘制每个检测框
    for box in results.boxes.data:
        # 获取坐标和置信度
        x1, y1, x2, y2, conf, cls = box
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])  # 转换为整数
        
        # 绘制边界框
        cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
        
        # 获取类别名称
        cls_name = results.names[int(cls)]
        
        # 添加标签文本
        label = f'{cls_name} '
        cv2.putText(img, label, (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 
                    0.5, (0, 255, 0), 2)
    
    return img

# img = detect_sign("./runs/detect/train45/weights/best.pt", "./datasets/datasets_hw/images/train/frame55.jpg")
# cv2.imshow("Detection", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt

def detect_line(image):
    # 读取和处理图像的代码保持不变...
    #image = cv2.imread(image_path)
    height, width = image.shape[:2]
    
    # 定义感兴趣区域的顶点
    # 这里我们创建一个梯形区域，这个区域通常包含了车道线的主要部分
    roi_vertices = np.array([
        # 左下角
        [width * 0, height],
        # 左上角
        [width * 0, height * 0.25],
        # 右上角
        [width * 0.9, height * 0.25],
        # 右下角
        [width * 1, height]
    ], dtype=np.int32)
     # 创建ROI掩码
    roi_mask = np.zeros_like(image)
    cv2.fillPoly(roi_mask, [roi_vertices], (255, 255, 255))
    
    # 1. 颜色检测部分
    # 转换到HSV空间
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    
    # 白色阈值（调整饱和度范围来处理反光）
    white_lower = np.array([0, 0, 200])
    white_upper = np.array([180, 40, 240])
    
    # 黄色阈值
    yellow_lower = np.array([15, 80, 80])
    yellow_upper = np.array([45, 255, 255])
    
    # 创建颜色掩码
    white_mask = cv2.inRange(hsv, white_lower, white_upper)
    yellow_mask = cv2.inRange(hsv, yellow_lower, yellow_upper)
    color_mask = cv2.bitwise_or(white_mask, yellow_mask)
    
    # 2. 边缘检测部分
    # 转换到灰度图
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # 使用高斯模糊减少噪声
    blurred = cv2.GaussianBlur(gray, (7, 7), 0)
    
    # Canny边缘检测
    # 使用较低的阈值来检测更多的边缘
    edges = cv2.Canny(blurred, 50, 150)  # More selective thresholds
    
    # 3. 组合颜色检测和边缘检测的结果
    # 使用形态学操作来加强边缘连接
    kernel = np.ones((3,3), np.uint8)
    dilated_edges = cv2.dilate(edges, kernel, iterations=1)
    

    # 计算边缘强度图
    sobelx = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
    sobely = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)
    edge_magnitude = np.sqrt(sobelx**2 + sobely**2)
    
    # 设定边缘强度阈值
    edge_threshold = np.mean(edge_magnitude) * 1.5
    strong_edges = (edge_magnitude > edge_threshold).astype(np.uint8) * 255
    
    # 将强边缘与 Canny 边缘结合
    final_edges = cv2.bitwise_and(edges, strong_edges)
        
    #将颜色掩码和边缘检测结果相与
    combined_mask = cv2.bitwise_and(color_mask,final_edges)
    
    # 应用ROI掩码
    final_mask = cv2.bitwise_and(combined_mask, roi_mask[:,:,0])
    # 然后再进行霍夫变换
    lines = cv2.HoughLinesP(
        final_mask,
        rho=1,
        theta=np.pi/180,
        threshold=50,
        minLineLength=25,
        maxLineGap=40
    )
        
    # 创建结果图像
    result = image.copy()
    
    # 在绘制检测到的直线之前添加以下代码
    # if lines is not None:
    #     filtered_lines = []
    #     for line in lines:
    #         x1, y1, x2, y2 = line[0]
    #         # 计算线段角度
    #         angle = abs(np.arctan2(y2 - y1, x2 - x1) * 180 / np.pi)
    #         
    #         # 筛选接近垂直的线条（可以调整角度范围）
    #         # 车道线通常在20-70度之间
    #         if (20 <= angle <= 70) or (110 <= angle <= 160):
    #             filtered_lines.append(line)
    #     
    #     # 使用筛选后的线条绘制
    #     for line in filtered_lines:
    #         x1, y1, x2, y2 = line[0]
    #         cv2.line(result, (x1, y1), (x2, y2), (0, 0, 255), 2)
        
    # 绘制检测到的直线
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            #print(line)
            cv2.line(result, (x1, y1), (x2, y2), (0, 0, 255), 1)
    if result is None:
        print("警告：生成的结果图像为空")
        return None
        
    # 确保图像是uint8类型
    if result.dtype != np.uint8:
        result = result.astype(np.uint8)
        
    # 确保图像是BGR格式（OpenCV需要的格式）
    if len(result.shape) != 3 or result.shape[2] != 3:
        print("警告：输出图像格式不正确")
        return None
        
    # 在返回之前进行验证
    try:
        # 测试是否可以编码为视频帧
        _, test_encode = cv2.imencode('.jpg', result)
        if not test_encode.any():
            print("警告：图像编码测试失败")
            return None
    except Exception as e:
        print(f"警告：图像处理出错 - {e}")
        return None

    # # 显示处理过程
    # plt.figure(figsize=(15, 10))
    # 
    # plt.subplot(2, 3, 1)
    # plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    # plt.title('原始图像')
    # 
    # plt.subplot(2, 3, 2)
    # plt.imshow(color_mask, cmap='gray')
    # plt.title('颜色检测')
    # 
    # plt.subplot(2, 3, 3)
    # plt.imshow(edges, cmap='gray')
    # plt.title('Canny边缘检测')
    # 
    # plt.subplot(2, 3, 4)
    # plt.imshow(final_mask, cmap='gray')
    # plt.title('组合结果')
    # 
    # plt.subplot(2, 3, 5)
    # plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
    # plt.title('最终检测结果')
    # 
    # # 显示带ROI的结果
    # debug_image = result.copy()
    # cv2.polylines(debug_image, [roi_vertices], True, (0, 255, 0), 2)
    # 
    # plt.subplot(2, 3, 6)
    # plt.imshow(cv2.cvtColor(debug_image, cv2.COLOR_BGR2RGB))
    # plt.title('带ROI的结果')
    # 
    # plt.tight_layout()
    # plt.show()

    return result

# %%
def process_video(video_path, output_path):
    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))
    count = 0
    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                break
                
            print(f"Processing frame: {count}")
            count += 1
            
            # 处理帧
            pr_frame = detect_line(frame)
            pr_frame = detect_sign("./runs/detect/train45/weights/best.pt", pr_frame)
            
            if pr_frame is not None:
                out.write(pr_frame)
                
    finally:
        # 确保资源被正确释放
        cap.release()
        out.release()
        cv2.destroyAllWindows()

# %%
process_video("./video.mp4", "./final.mp4")
# Out:
# Processing frame: 0
#
# 0: 384x640 (no detections), 12.5ms
# Speed: 13.2ms preprocess, 12.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 1
#
# 0: 384x640 (no detections), 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 2
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 1.2ms preprocess, 9.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 3
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 4
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 5
#
# 0: 384x640 (no detections), 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 6
#
# 0: 384x640 (no detections), 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 7
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 8
#
# 0: 384x640 (no detections), 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 9
#
# 0: 384x640 (no detections), 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 10
#
# 0: 384x640 (no detections), 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 11
#
# 0: 384x640 (no detections), 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 12
#
# 0: 384x640 (no detections), 9.6ms
# Speed: 1.5ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 13
#
# 0: 384x640 (no detections), 9.5ms
# Speed: 1.1ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 14
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 15
#
# 0: 384x640 (no detections), 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 16
#
# 0: 384x640 (no detections), 7.9ms
# Speed: 0.5ms preprocess, 7.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 17
#
# 0: 384x640 (no detections), 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 18
#
# 0: 384x640 (no detections), 6.9ms
# Speed: 1.0ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 19
#
# 0: 384x640 (no detections), 6.8ms
# Speed: 2.3ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 20
#
# 0: 384x640 (no detections), 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 21
#
# 0: 384x640 (no detections), 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 22
#
# 0: 384x640 (no detections), 7.7ms
# Speed: 1.2ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 23
#
# 0: 384x640 (no detections), 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 24
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 25
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 4.1ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 26
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 5.2ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 27
#
# 0: 384x640 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 28
#
# 0: 384x640 (no detections), 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 29
#
# 0: 384x640 (no detections), 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 30
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 31
#
# 0: 384x640 (no detections), 7.5ms
# Speed: 1.2ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 32
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 33
#
# 0: 384x640 (no detections), 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 34
#
# 0: 384x640 1 left, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 35
#
# 0: 384x640 1 left, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 36
#
# 0: 384x640 1 left, 8.2ms
# Speed: 1.0ms preprocess, 8.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 37
#
# 0: 384x640 1 left, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 38
#
# 0: 384x640 1 left, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 39
#
# 0: 384x640 1 left, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 40
#
# 0: 384x640 1 left, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 41
#
# 0: 384x640 1 left, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 42
#
# 0: 384x640 1 left, 8.2ms
# Speed: 0.5ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 43
#
# 0: 384x640 1 left, 6.9ms
# Speed: 1.1ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 44
#
# 0: 384x640 1 left, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 45
#
# 0: 384x640 1 left, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 46
#
# 0: 384x640 1 left, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 47
#
# 0: 384x640 1 left, 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 48
#
# 0: 384x640 1 left, 10.4ms
# Speed: 1.2ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 49
#
# 0: 384x640 1 left, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 50
#
# 0: 384x640 1 left, 8.4ms
# Speed: 1.5ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 51
#
# 0: 384x640 1 left, 9.9ms
# Speed: 1.2ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 52
#
# 0: 384x640 1 left, 6.8ms
# Speed: 1.0ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 53
#
# 0: 384x640 1 left, 6.6ms
# Speed: 1.1ms preprocess, 6.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 54
#
# 0: 384x640 1 left, 6.8ms
# Speed: 1.0ms preprocess, 6.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 55
#
# 0: 384x640 1 left, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 56
#
# 0: 384x640 1 left, 8.8ms
# Speed: 1.0ms preprocess, 8.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 57
#
# 0: 384x640 1 left, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 58
#
# 0: 384x640 1 left, 9.1ms
# Speed: 1.1ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 59
#
# 0: 384x640 1 left, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 60
#
# 0: 384x640 1 left, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 61
#
# 0: 384x640 (no detections), 12.2ms
# Speed: 0.5ms preprocess, 12.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 62
#
# 0: 384x640 (no detections), 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 63
#
# 0: 384x640 (no detections), 6.8ms
# Speed: 0.5ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 64
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 65
#
# 0: 384x640 (no detections), 7.8ms
# Speed: 2.0ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 66
#
# 0: 384x640 (no detections), 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 67
#
# 0: 384x640 1 right, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 68
#
# 0: 384x640 1 right, 9.4ms
# Speed: 1.0ms preprocess, 9.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 69
#
# 0: 384x640 1 right, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 70
#
# 0: 384x640 1 right, 6.9ms
# Speed: 1.0ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 71
#
# 0: 384x640 1 right, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 72
#
# 0: 384x640 1 right, 9.2ms
# Speed: 1.1ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 73
#
# 0: 384x640 1 right, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 74
#
# 0: 384x640 1 right, 8.9ms
# Speed: 1.3ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 75
#
# 0: 384x640 1 right, 10.1ms
# Speed: 1.0ms preprocess, 10.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 76
#
# 0: 384x640 1 right, 10.4ms
# Speed: 1.4ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 77
#
# 0: 384x640 1 right, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 78
#
# 0: 384x640 1 right, 13.1ms
# Speed: 2.2ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 79
#
# 0: 384x640 1 right, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 80
#
# 0: 384x640 1 right, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 81
#
# 0: 384x640 1 right, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 82
#
# 0: 384x640 1 right, 7.1ms
# Speed: 1.5ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 83
#
# 0: 384x640 1 right, 7.8ms
# Speed: 1.1ms preprocess, 7.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 84
#
# 0: 384x640 1 right, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 85
#
# 0: 384x640 1 right, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 86
#
# 0: 384x640 1 right, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 87
#
# 0: 384x640 1 right, 7.1ms
# Speed: 0.8ms preprocess, 7.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 88
#
# 0: 384x640 1 right, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 89
#
# 0: 384x640 1 right, 9.3ms
# Speed: 0.8ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 90
#
# 0: 384x640 1 right, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 91
#
# 0: 384x640 1 right, 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 92
#
# 0: 384x640 1 right, 11.2ms
# Speed: 1.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 93
#
# 0: 384x640 1 right, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 94
#
# 0: 384x640 1 right, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 95
#
# 0: 384x640 1 right, 10.7ms
# Speed: 1.3ms preprocess, 10.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 96
#
# 0: 384x640 1 right, 7.6ms
# Speed: 1.4ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 97
#
# 0: 384x640 1 right, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 98
#
# 0: 384x640 1 right, 8.3ms
# Speed: 1.2ms preprocess, 8.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 99
#
# 0: 384x640 1 right, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 100
#
# 0: 384x640 1 right, 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 101
#
# 0: 384x640 1 right, 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 102
#
# 0: 384x640 1 right, 8.1ms
# Speed: 1.1ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 103
#
# 0: 384x640 1 right, 9.6ms
# Speed: 1.9ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 104
#
# 0: 384x640 1 right, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 105
#
# 0: 384x640 1 right, 7.5ms
# Speed: 1.1ms preprocess, 7.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 106
#
# 0: 384x640 1 right, 8.1ms
# Speed: 1.1ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 107
#
# 0: 384x640 1 right, 15.0ms
# Speed: 2.5ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 108
#
# 0: 384x640 1 right, 14.5ms
# Speed: 3.1ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 109
#
# 0: 384x640 1 right, 15.6ms
# Speed: 3.5ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 110
#
# 0: 384x640 1 right, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 111
#
# 0: 384x640 1 right, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 112
#
# 0: 384x640 1 right, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 113
#
# 0: 384x640 1 right, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 114
#
# 0: 384x640 1 right, 14.0ms
# Speed: 3.5ms preprocess, 14.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 115
#
# 0: 384x640 1 right, 14.3ms
# Speed: 3.1ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 116
#
# 0: 384x640 1 right, 14.4ms
# Speed: 1.6ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 117
#
# 0: 384x640 1 right, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 118
#
# 0: 384x640 1 right, 14.2ms
# Speed: 1.5ms preprocess, 14.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 119
#
# 0: 384x640 1 right, 14.4ms
# Speed: 3.1ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 120
#
# 0: 384x640 1 right, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 121
#
# 0: 384x640 1 right, 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 122
#
# 0: 384x640 1 right, 18.1ms
# Speed: 1.5ms preprocess, 18.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 123
#
# 0: 384x640 1 right, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 124
#
# 0: 384x640 1 right, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 125
#
# 0: 384x640 (no detections), 13.7ms
# Speed: 2.3ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 126
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 127
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 2.6ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 128
#
# 0: 384x640 (no detections), 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 129
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 130
#
# 0: 384x640 (no detections), 17.3ms
# Speed: 1.6ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 131
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 2.2ms preprocess, 18.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 132
#
# 0: 384x640 (no detections), 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 133
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 134
#
# 0: 384x640 (no detections), 18.4ms
# Speed: 3.2ms preprocess, 18.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 135
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 136
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 137
#
# 0: 384x640 (no detections), 14.4ms
# Speed: 3.1ms preprocess, 14.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 138
#
# 0: 384x640 (no detections), 16.4ms
# Speed: 1.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 139
#
# 0: 384x640 (no detections), 14.2ms
# Speed: 2.5ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 140
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 141
#
# 0: 384x640 (no detections), 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 142
#
# 0: 384x640 (no detections), 22.0ms
# Speed: 4.4ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 143
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 144
#
# 0: 384x640 (no detections), 18.9ms
# Speed: 2.2ms preprocess, 18.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 145
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 146
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 147
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 2.5ms preprocess, 14.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 148
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 149
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 2.2ms preprocess, 15.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 150
#
# 0: 384x640 (no detections), 14.0ms
# Speed: 1.9ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 151
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 152
#
# 0: 384x640 (no detections), 31.6ms
# Speed: 2.2ms preprocess, 31.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 153
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 1.0ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 154
#
# 0: 384x640 (no detections), 14.1ms
# Speed: 2.1ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 155
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 1.0ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 156
#
# 0: 384x640 (no detections), 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 157
#
# 0: 384x640 (no detections), 13.2ms
# Speed: 1.0ms preprocess, 13.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 158
#
# 0: 384x640 1 stop, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 159
#
# 0: 384x640 1 stop, 13.9ms
# Speed: 1.4ms preprocess, 13.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 160
#
# 0: 384x640 1 stop, 13.9ms
# Speed: 1.8ms preprocess, 13.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 161
#
# 0: 384x640 1 stop, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 162
#
# 0: 384x640 1 stop, 7.5ms
# Speed: 2.0ms preprocess, 7.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 163
#
# 0: 384x640 1 stop, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 164
#
# 0: 384x640 1 stop, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 165
#
# 0: 384x640 1 stop, 25.1ms
# Speed: 1.8ms preprocess, 25.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 166
#
# 0: 384x640 1 stop, 7.0ms
# Speed: 1.3ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 167
#
# 0: 384x640 1 stop, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 168
#
# 0: 384x640 1 stop, 7.7ms
# Speed: 2.2ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 169
#
# 0: 384x640 1 stop, 7.7ms
# Speed: 1.1ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 170
#
# 0: 384x640 1 stop, 8.4ms
# Speed: 1.1ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 171
#
# 0: 384x640 1 stop, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 172
#
# 0: 384x640 1 stop, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 173
#
# 0: 384x640 1 stop, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 174
#
# 0: 384x640 1 stop, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 175
#
# 0: 384x640 1 stop, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 176
#
# 0: 384x640 1 stop, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 177
#
# 0: 384x640 1 stop, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 178
#
# 0: 384x640 1 stop, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing frame: 179
#
# 0: 384x640 1 stop, 10.3ms
# Speed: 1.0ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
